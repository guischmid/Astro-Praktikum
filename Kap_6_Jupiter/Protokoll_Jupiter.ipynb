# %% [markdown]
# # Kapitel 6 Protkoll: Jupiter
# Guilherme Scmid

# %% [markdown]
# ## Beobachtungen
#
# 1. lineare Abstände x des jeweiligen Mondes zum Jupiter in mm.
#
#
# <div style="display: flex; justify-content: space-around;">
#   <div>
#     <h3>IO</h3>
#     <table>
#       <tr><th>Abstand</th><th>Datum</th><th>Uhrzeit</th></tr>
#       <tr><td>6mm</td><td>27. Mar</td><td>02:00</td></tr>
#       <tr><td>9mm</td><td>27. Mar</td><td>04:00</td></tr>
#       <tr><td>19mm</td><td>27. Mar</td><td>07:00</td></tr>
#       <tr><td>10mm</td><td>27. Mar</td><td>08:00</td></tr>
#       <tr><td>9mm</td><td>27. Mar</td><td>10:00</td></tr>
#       <tr><td>8mm</td><td>27. Mar</td><td>11:00</td></tr>
#       <tr><td>7mm</td><td>27. Mar</td><td>12:00</td></tr>
#     </table>
#   </div>
#   <div>
#     <h3>Europa</h3>
#     <table>
#       <tr><th>Abstand</th><th>Datum</th><th>Uhrzeit</th></tr>
#       <tr><td>15mm</td><td>27. Mar</td><td>02:00</td></tr>
#       <tr><td>17mm</td><td>27. Mar</td><td>04:00</td></tr>
#       <tr><td>18mm</td><td>27. Mar</td><td>07:00</td></tr>
#       <tr><td>18mm</td><td>27. Mar</td><td>08:00</td></tr>
#       <tr><td>18mm</td><td>27. Mar</td><td>10:00</td></tr>
#       <tr><td>4mm</td><td>28. Mar</td><td>02:00</td></tr>
#       <tr><td>0.5mm</td><td>28. Mar</td><td>06:00</td></tr>
#     </table>
#   </div>
#   <div>
#     <h3>Ganymed</h3>
#     <table>
#       <tr><th>Abstand</th><th>Datum</th><th>Uhrzeit</th></tr>
#       <tr><td>1mm</td><td>31. Mar</td><td>05:10</td></tr>
#       <tr><td>27mm</td><td>31. Mar</td><td>10:45</td></tr>
#       <tr><td>8mm</td><td>01. Mar</td><td>06:00</td></tr>
#       <tr><td>29mm</td><td>01. Mar</td><td>09:45</td></tr>
#       <tr><td>31mm</td><td>02. Mar</td><td>03:20</td></tr>
#       <tr><td>14mm</td><td>03. Mar</td><td>02:50</td></tr>
#       <tr><td>8mm</td><td>03. Mar</td><td>06:45</td></tr>
#       <tr><td>3mm</td><td>03. Mar</td><td>10:55</td></tr>
#     </table>
#   </div>
#   <div>
#     <h3>Kallisto</h3>
#     <table>
#       <tr><th>Abstand</th><th>Datum</th><th>Uhrzeit</th></tr>
#       <tr><td>22mm</td><td>30. Mar</td><td>05:45</td></tr>
#       <tr><td>40mm</td><td>31. Mar</td><td>05:10</td></tr>
#       <tr><td>52mm</td><td>01. Apr</td><td>06:00</td></tr>
#       <tr><td>54mm</td><td>03. Apr</td><td>02:50</td></tr>
#       <tr><td>52mm</td><td>03. Apr</td><td>11:00</td></tr>
#       <tr><td>26mm</td><td>05. Apr</td><td>03:15</td></tr>
#       <tr><td>5mm</td><td>06. Apr</td><td>02:40</td></tr>
#       <tr><td>1mm</td><td>06. Apr</td><td>07:40</td></tr>
#     </table>
#   </div>
# </div>
#
# 2. Die Zeitangaben wurden in fortlaufende Stunden umgerechnet:
#
# IO
#
# 	•	6 mm, 27. Mar, 02:00 → 2 Stunden
# 	•	9 mm, 27. Mar, 04:00 → 4 Stunden
# 	•	19 mm, 27. Mar, 07:00 → 7 Stunden
# 	•	10 mm, 27. Mar, 08:00 → 8 Stunden
# 	•	9 mm, 27. Mar, 10:00 → 10 Stunden
# 	•	8 mm, 27. Mar, 11:00 → 11 Stunden
# 	•	7 mm, 27. Mar, 12:00 → 12 Stunden
#
# Europa
#
# 	•	15mm, 27. Mar, 02:00→ 2 Stunden
# 	•	17 mm, 27. Mar, 04:00 → 4 Stunden
# 	•	18 mm, 27. Mar, 07:00 → 7 Stunden
# 	•	18 mm, 27. Mar, 08:00 → 8 Stunden
# 	•	18 mm, 27. Mar, 10:00 → 10 Stunden
# 	•	4 mm, 28. Mar, 02:00 → 26 Stunden (1 Tag + 2 Stunden)
# 	•	0.5 mm, 28. Mar, 06:00 → 30 Stunden (1 Tag + 6 Stunden)
#
# Ganymed
#
# 	•	1 mm, 31. Mar, 05:10 → 77.17 Stunden (3 Tage + 5 Stunden + 10 Minuten)
# 	•	27 mm, 31. Mar, 10:45 → 82.75 Stunden (3 Tage + 10 Stunden + 45 Minuten)
# 	•	8 mm, 1. Apr, 06:00 → 102 Stunden (4 Tage + 6 Stunden)
# 	•	29 mm, 1. Apr, 09:45 → 105.75 Stunden (4 Tage + 9 Stunden + 45 Minuten)
# 	•	31 mm, 2. Apr, 03:20 → 123.33 Stunden (5 Tage + 3 Stunden + 20 Minuten)
# 	•	14 mm, 3. Apr, 02:50 → 146.83 Stunden (6 Tage + 2 Stunden + 50 Minuten)
# 	•	8 mm, 3. Apr, 06:45 → 150.75 Stunden (6 Tage + 6 Stunden + 45 Minuten)
# 	•	3 mm, 3. Apr, 10:55 → 154.92 Stunden (6 Tage + 10 Stunden + 55 Minuten)
#
# Kallisto
#
# 	•	22 mm, 30. Mar, 05:45 → 77.75 Stunden (3 Tage + 5 Stunden + 45 Minuten)
# 	•	40 mm, 31. Mar, 05:10 → 101.17 Stunden (4 Tage + 5 Stunden + 10 Minuten)
# 	•	52 mm, 1. Apr, 06:00 → 126 Stunden (5 Tage + 6 Stunden)
# 	•	54 mm, 3. Apr, 02:50→ 170.83 Stunden (7 Tage + 2 Stunden + 50 Minuten)
# 	•	52 mm, 3. Apr, 11:00 → 179 Stunden (7 Tage + 11 Stunden)
# 	•	26 mm, 5. Apr, 03:15 → 221.25 Stunden (9 Tage + 3 Stunden + 15 Minuten)
# 	•	5 mm, 6. Apr, 02:40 → 242.67 Stunden (10 Tage + 2 Stunden + 40 Minuten)
# 	•	1 mm, 6. Apr, 07:40 → 247.67 Stunden (10 Tage + 7 Stunden + 40 Minuten)
#
# 3. Kalibrationsfaktor der Skala in $^{\circ}/mm$.
